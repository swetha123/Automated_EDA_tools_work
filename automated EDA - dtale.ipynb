# %% [markdown]
# # dtale

# %%
# !pip install dtale
# Out:
# ...
#      ---------------------------------------- 14.2/14.2 MB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 10.4/10.4 MB 2.4 MB/s eta 0:00:00
# ...
#      ------------------------------------ 219.7/219.7 kB 956.5 kB/s eta 0:00:00
# ...
#      ------------------------------------ 642.7/642.7 kB 763.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 45.9/45.9 kB 774.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.9/65.9 MB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.3/62.3 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 96.5/96.5 kB 345.2 kB/s eta 0:00:00
# ...
#      ------------------------------------ 383.3/383.3 kB 543.1 kB/s eta 0:00:00
# ...

# %%
import dtale
import pandas as pd

# %%
df1 = pd.read_csv("E:\data science\Dataset\data3\googleplaystore.csv")

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
d1 = dtale.show(df1)
#d1.open_browser()
# Out:
# C:\Users\Swetha\anaconda3\lib\site-packages\dtale\views.py:778: FutureWarning:
#
# ['Type', 'Content Rating', 'Current Ver', 'Android Ver'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#
# 2023-07-25 22:16:02,401 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,517 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,517 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,534 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,545 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,553 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,558 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-07-25 22:16:02,569 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %%
d1
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-H927GV9P:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df2 = pd.read_csv("E:\data science\Dataset\data5\Visadataset.csv")

# %%
df2.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
d2 = dtale.show(df2)

# %%
d2
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-H927GV9P:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
